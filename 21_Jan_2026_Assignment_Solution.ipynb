# %% [markdown]
# # Python Logic & Loops: Real-World Assignment (21-01-2026-UDS-2.0)

# %% [markdown]
# ##
# 1. The Office Door Badge You are programming a smart door for a tech office. The door should only open if the
# user provides the correct "Access Code."
# Input: User enters a 4-digit code.
# Scenario: If the code is
# 1234 , print "Access Granted. Door Unlocked." Otherwise, print "Access Denied.
# Security Alerted.

# %%
User_Code= int(input("Please Enter 4 digit Code"))
Check_Code= 1234

if User_Code == Check_Code:
        print("Access Granted")
else:
        print("Access Denied. Security Alerted")
# Out:
# Access Granted

# %% [markdown]
# ##
# 2. The Weekend Grocery Trip A person is deciding whether to go to the supermarket.
# Input: User enters how many eggs are left in the fridge (integer).
# Scenario: If the number of eggs is less than 3, print "Time to go to the market!" Else, print "You have
# enough for breakfast today.

# %%
User_Input = int(input("Tell me how many number of EGGs are in Fridge"))
Egg_Threshold = 3
if User_Input < Egg_Threshold:
     print("Time to go to the market!")
else:
    print("You have enough for breakfast")
# Out:
# You have enough for breakfast

# %% [markdown]
# ##
# 3. The Smart Home "Leaving for Work" Checklist When you leave your house, a smart assistant checks multiple
# independent things. These are not mutually exclusive.
# Input: Three separate inputs (Yes/No) for: "Is the AC on?", "Is the Coffee Maker on?", "Is the Front Door
# unlocked?"
#
# Scenario:
# 1. If AC is on Print "Turning off AC to save energy."
# 2. If Coffee Maker is on Print "Warning: Coffee Maker is still hot!"
# 3. If Door is unlocked Print "Locking the front door now." (Note: All three messages could potentially print.)

# %%
ac = input("Is the AC on? (Yes/No): ").strip().lower()
coffe = input("Is the coffe machine on? (Yes/No): ").strip().lower()
door = input("Is the AC on? (Yes/No): ").strip().lower()

if ac and coffe and door!="yes":
    print(f"Please enter valid input {"Yes"} or {"No"} only")
if ac=="yes":
        print("Turning off AC to save energy")
if coffe=="yes":
        print("Warning: Coffee Maker is still hot!")
if door == "yes":
        print("Locking the front door now.")

# %% [markdown]
# ##
# 4. The Pizza Topping Calculator A customer is choosing toppings. Each topping adds a specific cost regardless of
# the other toppings chosen.
#     Input: Three boolean (True/False) inputs for:
# Scenario: Initialize a  If total_bill = 10 .
#     1. extra_cheese is True add 2 to bill.
#     2. If  pepperoni is True add 3 to bill.
#     3. If olives is True add 1 to bill.
#
# Output: Print the final total bill

# %%
base_bill = int(input("entre base price"))
cheese = input("Do you want extra chesse as topping").lower().strip()
pepperoni = input("Do you want extra pepperoni as topping").lower().strip()
olives = input("Do you want extra olives as topping")
valid= ['yes','y','no,n']
if cheese not in valid or pepperoni not in valid or olives not in valid:
    print("Please select Yes or No only")
else:
    total_bill =base_bill
    if cheese in ['yes','y']:
        total_bill +=2
    if olives in ['yes','y']:
        total_bill +=1
    if pepperoni in ['yes','y']:
        total_bill += 3
    print("Total bill is : ",total_bill)
# Out:
# Total bill is :  26

# %% [markdown]
# ##
# 5. The Traffic Light Sensor A self-driving car needs to interpret a single traffic light color.
# Input: User enters "Red", "Yellow", or "Green".
# Scenario:
#     1. If "Red" "Full Stop."
#     2. If "Yellow" "Slow down and prepare to stop."
#     3. If "Green" "Proceed with caution."
#     4. Anything else "Error: Signal Malfunction!

# %%
User_Input= input(f"Tell me colour of light, {"Red"} {" Yellow"}{" Green"}").lower().strip()
valid_inputs = ['red','r','yellow','y','green','g']
if User_Input not in valid:
    print("Error. Signal Malfunction")
else:
    if User_Input in ['red','r']:
        print("Full Stop")
    elif User_Input in ['Yellow','y']:
        print("Slow down and prepare to stop")
    elif User_Input in ['green','g']:
        print("Proceed with caution")
# Out:
# Error. Signal Malfunction

# %% [markdown]
# ##
# 6. Movie Theater Ticket Pricing A theater charges based on the age of the customer.
#     Input: User enters their age.
#     Scenario:
#     1. Age < 5 "Ticket is Free."
#     2. Age 5 to 17 "Child Ticket: $10."
#     3. Age 18 to 60 "Adult Ticket: $18."
#     4. Age > 60 "Senior Ticket: $12.

# %%
user_age = int(input("Enter you age"))
if user_age<5:
    print('Ticket is free')
elif 5<=user_age<=17:
    print("Child Ticket is $10.00")
elif 18<=user_age<=60:
    print("Adult ticket is $18.00")
else:
    print("Your age is :",user_age," Ticket is free")
# Out:
# Adult ticket is $18.00

# %% [markdown]
# ##
# 7. The 7-Day Steps Tracker A fitness app wants to show your activity for the week.
# Data:
#     1. A list of steps: [4000, 7500, 10000, 2000, 8000, 12000, 5000] .
#     2. Scenario: Loop through the list and for each day, print: "Day [X]: You walked [Steps] steps."

# %%
steps = [4000,7500,10000,2000,8000,12000,5000]

for i in range (len(steps)):
    print(f"Day {i}: You walked {steps[i]} steps")
# Out:
# Day 0: You walked 4000 steps
# Day 1: You walked 7500 steps
# Day 2: You walked 10000 steps
# Day 3: You walked 2000 steps
# Day 4: You walked 8000 steps
# Day 5: You walked 12000 steps
# Day 6: You walked 5000 steps

# %% [markdown]
# ##
# 8. The Email "Bcc" System A marketing manager has a list of 5 client names.
# Input: A list containing 5 names.
# Scenario: Use a loop to "send" an email to each person by printing: "Sending personalized promo code to
# [Name]...

# %%
client_list = ["Monal","Krish","Sanny","Mayank","Dhiraj"]

for name in range(len(client_list)):
    print(f"Sending personalized promo cod to {client_list[name]}")
# Out:
# Sending personalized promo cod to Monal
# Sending personalized promo cod to Krish
# Sending personalized promo cod to Sanny
# Sending personalized promo cod to Mayank
# Sending personalized promo cod to Dhiraj
